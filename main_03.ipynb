# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns


df= pd.read_csv('cleaned_ffod_delivery_times.csv')

# %%
sns.violinplot(
    data=df,
    x='Traffic_Level',y='Delivery_Time_min'
)
# Out:
# <Axes: xlabel='Traffic_Level', ylabel='Delivery_Time_min'>

# %%
sns.pairplot(df)

# %%
sns.kdeplot(df['Delivery_Time_min'], fill=True)
plt.title("Smooth Distribution")
# Out:
# Text(0.5, 1.0, 'Smooth Distribution')

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
